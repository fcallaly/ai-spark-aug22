# %%
# import os
# os.environ['PYSPARK_PYTHON'] = 'python'

# %%
import pyspark

# %% [markdown]
# We configure our "SparkContext" at the start - e.g. configuration options to be passed to all worker/executor nodes

# %%
# NOTE - we're running in 'local' context,
# this could be changed later to use a resource/cluster manager e.g.YARN or Spark Standalone
from pyspark.sql import SparkSession

sparkSession = SparkSession.builder.master('local[*]') \
                                   .appName('LocalSparkSql').getOrCreate()

# %% [markdown]
# Some alternatives to the above that might be used IF we had a cluster available

# %%
# Example using a Spark Standalone cluster manager - on a host called "spark-master" listening on port 7077
# spark = SparkSession.builder.master('spark://spark-master:7077')\
#                             .appName('LocalSparkSql').getOrCreate()

# Example using a Yarn cluster manager
# spark = SparkSession.builder.master('yarn')\
#                             .appName('LocalSparkSql').getOrCreate()


# Example setting some configuration parameters
# spark = SparkSession.builder.master('spark://spark-master:7077')\
#                             .config('spark.executor.memory', '512M')\
#                             .appName('LocalSparkSql').getOrCreate()

# %%
sparkSession

# right-click on the "Spark UI" link and "Open in another tab" - this shows you what this Spark App is doing
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-2VQM1NI:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.4</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>LocalSparkSql</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# Spark can read from many data sources
#
# In this case we'll read a CSV file containing a table of airports from the local filesystem

# %%
# Update if the file is somewhere else relative to the notebook
CSV_LOCATION = 'data/airports.csv'

# e.g. if in a hadoop context, would commonly read from HDFS or S3
#CSV_LOCATION = "hdfs://hadoop-master:9000/user/frank/airports.csv"

# %%
airportsDf = sparkSession.read.csv(CSV_LOCATION, header=True)

# Some spark dataframe operations - count and "take"
print(airportsDf.count())
airportsDf.take(5)
# Out:
# 5741
# [Row(id='1', Name='Goroka Airport', City='Goroka', Country='Papua New Guinea', iataCode='GKA', icaoCode='AYGA', latitude='-6.081689834590001', longitude='145.391998291', altitude='5282', timezone='10', dst='U', timezoneOlsonFormat='Pacific/Port_Moresby', installationType='airport', datasource='OurAirports'),
#  Row(id='2', Name='Madang Airport', City='Madang', Country='Papua New Guinea', iataCode='MAG', icaoCode='AYMD', latitude='-5.20707988739', longitude='145.789001465', altitude='20', timezone='10', dst='U', timezoneOlsonFormat='Pacific/Port_Moresby', installationType='airport', datasource='OurAirports'),
#  Row(id='3', Name='Mount Hagen Kagamuga Airport', City='Mount Hagen', Country='Papua New Guinea', iataCode='HGU', icaoCode='AYMH', latitude='-5.826789855957031', longitude='144.29600524902344', altitude='5388', timezone='10', dst='U', timezoneOlsonFormat='Pacific/Port_Moresby', installationType='airport', datasource='OurAirports'),
#  Row(id='4', Name='Nadzab Airport', City='Nadzab', Country='Papua New Guinea', iataCode='LAE', icaoCode='AYNZ', latitude='-6.569803', longitude='146.725977', altitude='239', timezone='10', dst='U', timezoneOlsonFormat='Pacific/Port_Moresby', installationType='airport', datasource='OurAirports'),
#  Row(id='5', Name='Port Moresby Jacksons International Airport', City='Port Moresby', Country='Papua New Guinea', iataCode='POM', icaoCode='AYPY', latitude='-9.443380355834961', longitude='147.22000122070312', altitude='146', timezone='10', dst='U', timezoneOlsonFormat='Pacific/Port_Moresby', installationType='airport', datasource='OurAirports')]

# %%
# "show" is very similar to pandas "head" - in this case the data is potentially spread around a cluster
airportsDf.show(5)
# Out:
# +---+--------------------+------------+----------------+--------+--------+------------------+------------------+--------+--------+---+--------------------+----------------+-----------+
# | id|                Name|        City|         Country|iataCode|icaoCode|          latitude|         longitude|altitude|timezone|dst| timezoneOlsonFormat|installationType| datasource|
# +---+--------------------+------------+----------------+--------+--------+------------------+------------------+--------+--------+---+--------------------+----------------+-----------+
# |  1|      Goroka Airport|      Goroka|Papua New Guinea|     GKA|    AYGA|-6.081689834590001|     145.391998291|    5282|      10|  U|Pacific/Port_Moresby|         airport|OurAirports|
# |  2|      Madang Airport|      Madang|Papua New Guinea|     MAG|    AYMD|    -5.20707988739|     145.789001465|      20|      10|  U|Pacific/Port_Moresby|         airport|OurAirports|
# |  3|Mount Hagen Kagam...| Mount Hagen|Papua New Guinea|     HGU|    AYMH|-5.826789855957031|144.29600524902344|    5388|      10|  U|Pacific/Port_Moresby|         airport|OurAirports|
# |  4|      Nadzab Airport|      Nadzab|Papua New Guinea|     LAE|    AYNZ|         -6.569803|        146.725977|     239|      10|  U|Pacific/Port_Moresby|         airport|OurAirports|
# |  5|Port Moresby Jack...|Port Moresby|Papua New Guinea|     POM|    AYPY|-9.443380355834961|147.22000122070312|     146|      10|  U|Pacific/Port_Moresby|         airport|OurAirports|
# +---+--------------------+------------+----------------+--------+--------+------------------+------------------+--------+--------+---+--------------------+----------------+-----------+
# only showing top 5 rows

# %%
# what datatypes did spark detect - by default with csv it won't detect much - just strings for everything
airportsDf.dtypes
# Out:
# [('id', 'string'),
#  ('Name', 'string'),
#  ('City', 'string'),
#  ('Country', 'string'),
#  ('iataCode', 'string'),
#  ('icaoCode', 'string'),
#  ('latitude', 'string'),
#  ('longitude', 'string'),
#  ('altitude', 'string'),
#  ('timezone', 'string'),
#  ('dst', 'string'),
#  ('timezoneOlsonFormat', 'string'),
#  ('installationType', 'string'),
#  ('datasource', 'string')]

# %%
# filter for a particiular city
airportsDf.filter(airportsDf['City'] == 'San Diego').show()
# Out:
# +----+--------------------+---------+-------------+--------+--------+-------------+--------------+--------+--------+---+-------------------+----------------+-----------+
# |  id|                Name|     City|      Country|iataCode|icaoCode|     latitude|     longitude|altitude|timezone|dst|timezoneOlsonFormat|installationType| datasource|
# +----+--------------------+---------+-------------+--------+--------+-------------+--------------+--------+--------+---+-------------------+----------------+-----------+
# |3594|North Island Nava...|San Diego|United States|     NZY|    KNZY|  32.69919968|  -117.2149963|      26|      -8|  A|America/Los_Angeles|         airport|OurAirports|
# |3731|San Diego Interna...|San Diego|United States|     SAN|    KSAN|32.7336006165|-117.190002441|      17|      -8|  A|America/Los_Angeles|         airport|OurAirports|
# +----+--------------------+---------+-------------+--------+--------+-------------+--------------+--------+--------+---+-------------------+----------------+-----------+

# %% [markdown]
# ### Clean the dataset by changing some datatypes

# %%
# E.g. how many nulls in iataCode?
airportsDf.filter( airportsDf['iataCode'].isNull() ).count()
# Out:
# 0

# %% [markdown]
# ### Convert some datatypes so we can use them as numbers
# The datatypes in the csv were not detected, we can change types while cleaning our data

# %%
from pyspark.sql.types import DoubleType

print("original dtypes: ", airportsDf.dtypes)
print() # empty line

# change datatypes from string to double
airportsDf = airportsDf.withColumn("latitude", airportsDf["latitude"].cast(DoubleType()))
airportsDf = airportsDf.withColumn("longitude", airportsDf["longitude"].cast(DoubleType()))

print("updated dtypes: ", airportsDf.dtypes)
# Out:
# original dtypes:  [('id', 'string'), ('Name', 'string'), ('City', 'string'), ('Country', 'string'), ('iataCode', 'string'), ('icaoCode', 'string'), ('latitude', 'string'), ('longitude', 'string'), ('altitude', 'string'), ('timezone', 'string'), ('dst', 'string'), ('timezoneOlsonFormat', 'string'), ('installationType', 'string'), ('datasource', 'string')]
#
# updated dtypes:  [('id', 'string'), ('Name', 'string'), ('City', 'string'), ('Country', 'string'), ('iataCode', 'string'), ('icaoCode', 'string'), ('latitude', 'double'), ('longitude', 'double'), ('altitude', 'string'), ('timezone', 'string'), ('dst', 'string'), ('timezoneOlsonFormat', 'string'), ('installationType', 'string'), ('datasource', 'string')]

# %% [markdown]
# **Spark Dataframe filtering - similar, though slightly different from pandas syntax**

# %%
# As with all spark operations, we filter the dataframe (RDD) and produce a NEW dataframe (RDD)
tropAirports = airportsDf.filter((airportsDf["latitude"] > -23) & (airportsDf["latitude"] < 23))

# how many did we find?
print(tropAirports.count())
tropAirports.show(5)
# Out:
# 1742
# +---+--------------------+------------+----------------+--------+--------+------------------+------------------+--------+--------+---+--------------------+----------------+-----------+
# | id|                Name|        City|         Country|iataCode|icaoCode|          latitude|         longitude|altitude|timezone|dst| timezoneOlsonFormat|installationType| datasource|
# +---+--------------------+------------+----------------+--------+--------+------------------+------------------+--------+--------+---+--------------------+----------------+-----------+
# |  1|      Goroka Airport|      Goroka|Papua New Guinea|     GKA|    AYGA|-6.081689834590001|     145.391998291|    5282|      10|  U|Pacific/Port_Moresby|         airport|OurAirports|
# |  2|      Madang Airport|      Madang|Papua New Guinea|     MAG|    AYMD|    -5.20707988739|     145.789001465|      20|      10|  U|Pacific/Port_Moresby|         airport|OurAirports|
# |  3|Mount Hagen Kagam...| Mount Hagen|Papua New Guinea|     HGU|    AYMH|-5.826789855957031|144.29600524902344|    5388|      10|  U|Pacific/Port_Moresby|         airport|OurAirports|
# |  4|      Nadzab Airport|      Nadzab|Papua New Guinea|     LAE|    AYNZ|         -6.569803|        146.725977|     239|      10|  U|Pacific/Port_Moresby|         airport|OurAirports|
# |  5|Port Moresby Jack...|Port Moresby|Papua New Guinea|     POM|    AYPY|-9.443380355834961|147.22000122070312|     146|      10|  U|Pacific/Port_Moresby|         airport|OurAirports|
# +---+--------------------+------------+----------------+--------+--------+------------------+------------------+--------+--------+---+--------------------+----------------+-----------+
# only showing top 5 rows

# %% [markdown]
# **We can use SQL to query spark DataFrames**
#
# First use createOrReplaceTempView to create a representation of the table in memory

# %%
tropAirports.createOrReplaceTempView("tropAirports")

sparkSession.sql("SELECT DISTINCT(Country) FROM tropAirports").collect()
# Out:
# [Row(Country='Chad'),
#  Row(Country='Paraguay'),
#  Row(Country='Anguilla'),
#  Row(Country='British Indian Ocean Territory'),
#  Row(Country='Yemen'),
#  Row(Country='Senegal'),
#  Row(Country='Kiribati'),
#  Row(Country='Guyana'),
#  Row(Country='Philippines'),
#  Row(Country='Burma'),
#  Row(Country='Eritrea'),
#  Row(Country='Tonga'),
#  Row(Country='Djibouti'),
#  Row(Country='Malaysia'),
#  Row(Country='Singapore'),
#  Row(Country='Fiji'),
#  Row(Country='Malawi'),
#  Row(Country='Northern Mariana Islands'),
#  Row(Country='Comoros'),
#  Row(Country='Cambodia'),
#  Row(Country='Saint Helena'),
#  Row(Country='Rwanda'),
#  Row(Country='Maldives'),
#  Row(Country='Sudan'),
#  Row(Country='Palau'),
#  Row(Country='Turks and Caicos Islands'),
#  Row(Country='France'),
#  Row(Country='Sri Lanka'),
#  Row(Country='Montserrat'),
#  Row(Country='Taiwan'),
#  Row(Country='Dominica'),
#  Row(Country='British Virgin Islands'),
#  Row(Country='Algeria'),
#  Row(Country='Togo'),
#  Row(Country='Equatorial Guinea'),
#  Row(Country='Reunion'),
#  Row(Country='Macau'),
#  Row(Country='Argentina'),
#  Row(Country='Angola'),
#  Row(Country='East Timor'),
#  Row(Country='Ecuador'),
#  Row(Country='Madagascar'),
#  Row(Country='New Caledonia'),
#  Row(Country='Ghana'),
#  Row(Country='Nicaragua'),
#  Row(Country='Benin'),
#  Row(Country='Sierra Leone'),
#  Row(Country='Peru'),
#  Row(Country='Bahamas'),
#  Row(Country='India'),
#  Row(Country='China'),
#  Row(Country='United States'),
#  Row(Country='American Samoa'),
#  Row(Country='Sao Tome and Principe'),
#  Row(Country='Somalia'),
#  Row(Country='Marshall Islands'),
#  Row(Country='Tuvalu'),
#  Row(Country='Chile'),
#  Row(Country='Puerto Rico'),
#  Row(Country='Martinique'),
#  Row(Country='Cayman Islands'),
#  Row(Country='Burundi'),
#  Row(Country='Nigeria'),
#  Row(Country='Bolivia'),
#  Row(Country='Virgin Islands'),
#  Row(Country='Gabon'),
#  Row(Country='Suriname'),
#  Row(Country='Netherlands Antilles'),
#  Row(Country='Cuba'),
#  Row(Country='Mauritania'),
#  Row(Country='Guadeloupe'),
#  Row(Country='Congo (Kinshasa)'),
#  Row(Country='Niger'),
#  Row(Country='Central African Republic'),
#  Row(Country='Barbados'),
#  Row(Country='Bangladesh'),
#  Row(Country='Laos'),
#  Row(Country='Thailand'),
#  Row(Country='Christmas Island'),
#  Row(Country='Cocos (Keeling) Islands'),
#  Row(Country='Cape Verde'),
#  Row(Country='Panama'),
#  Row(Country='Hong Kong'),
#  Row(Country='Nauru'),
#  Row(Country='Venezuela'),
#  Row(Country='Saint Kitts and Nevis'),
#  Row(Country='French Polynesia'),
#  Row(Country='Oman'),
#  Row(Country="Cote d'Ivoire"),
#  Row(Country='Mexico'),
#  Row(Country='Aruba'),
#  Row(Country='Zimbabwe'),
#  Row(Country='Indonesia'),
#  Row(Country='Saint Vincent and the Grenadines'),
#  Row(Country='Guatemala'),
#  Row(Country='Guam'),
#  Row(Country='Grenada'),
#  Row(Country='Liberia'),
#  Row(Country='Honduras'),
#  Row(Country='Trinidad and Tobago'),
#  Row(Country='Congo (Brazzaville)'),
#  Row(Country='Saudi Arabia'),
#  Row(Country='Uganda'),
#  Row(Country='Wallis and Futuna'),
#  Row(Country='French Guiana'),
#  Row(Country='Mayotte'),
#  Row(Country='Namibia'),
#  Row(Country='Zambia'),
#  Row(Country='Ethiopia'),
#  Row(Country='Jamaica'),
#  Row(Country='South Sudan'),
#  Row(Country='Brunei'),
#  Row(Country='Johnston Atoll'),
#  Row(Country='Saint Lucia'),
#  Row(Country='Guinea'),
#  Row(Country='Seychelles'),
#  Row(Country='Samoa'),
#  Row(Country='Mozambique'),
#  Row(Country='Cook Islands'),
#  Row(Country='Belize'),
#  Row(Country='Brazil'),
#  Row(Country='Gambia'),
#  Row(Country='Kenya'),
#  Row(Country='Antigua and Barbuda'),
#  Row(Country='Dominican Republic'),
#  Row(Country='Botswana'),
#  Row(Country='Tanzania'),
#  Row(Country='Haiti'),
#  Row(Country='Papua New Guinea'),
#  Row(Country='Cameroon'),
#  Row(Country='Australia'),
#  Row(Country='Guinea-Bissau'),
#  Row(Country='Solomon Islands'),
#  Row(Country='Egypt'),
#  Row(Country='Costa Rica'),
#  Row(Country='El Salvador'),
#  Row(Country='Burkina Faso'),
#  Row(Country='Micronesia'),
#  Row(Country='Colombia'),
#  Row(Country='Vanuatu'),
#  Row(Country='Niue'),
#  Row(Country='Mauritius'),
#  Row(Country='Vietnam'),
#  Row(Country='Mali')]

# %%
sparkSession.sql('SELECT COUNT(*) FROM tropAirports WHERE Country = "Papua New Guinea"').show();
# Out:
# +--------+
# |count(1)|
# +--------+
# |      51|
# +--------+

# %% [markdown]
# **We could save the filtered table back to a filesystem or a database**

# %%
# Write a dataframe as csv to HDFS - similar to pandas to_csv
# tropAirports.write.format("csv").save("hdfs://hadoop-master:9000/user/ec2-user/tropAirports.csv", header=True)

# %% [markdown]
# ### For analytics we sometimes convert back to Pandas
#
# Once the dataframe is cut down to a manageable size, we may choose to convert to a pandas dataframe for further processing

# %%
pdTropAirports = tropAirports.toPandas()

# pdTropAirports is a pandas Dataframe, the original was a spark dataframe
print(type(tropAirports))
print(type(pdTropAirports))

# set IATA_CODE as the index
pdTropAirports.set_index("iataCode", inplace=True)
display(pdTropAirports)
# Out:
# <class 'pyspark.sql.dataframe.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
#             id                                         Name              City  \
# iataCode
# GKA          1                               Goroka Airport            Goroka
# MAG          2                               Madang Airport            Madang
# HGU          3                 Mount Hagen Kagamuga Airport       Mount Hagen
# LAE          4                               Nadzab Airport            Nadzab
# POM          5  Port Moresby Jacksons International Airport      Port Moresby
# WWK          6                  Wewak International Airport             Wewak
# TMR        216           Aguenar – Hadj Bey Akhamok Airport       Tamanrasset
# COO        245                            Cadjehoun Airport           Cotonou
# OUA        246                          Ouagadougou Airport       Ouagadougou
# BOY        247                       Bobo Dioulasso Airport    Bobo-dioulasso
# ACC        248                 Kotoka International Airport             Accra
# TML        249                               Tamale Airport            Tamale
# \N         250                                   Wa Airport                Wa
# NYI        251                              Sunyani Airport           Sunyani
# TKD        252                             Takoradi Airport          Takoradi
# ABJ        253                           Port Bouet Airport           Abidjan
# BYK        254                               Bouaké Airport            Bouake
# DJO        255                                Daloa Airport             Daloa
# HGO        256                              Korhogo Airport           Korhogo
# MJC        257                                  Man Airport               Man
# SPY        258                            San Pedro Airport         San Pedro
# ASK        259                         Yamoussoukro Airport      Yamoussoukro
# ABV        260         Nnamdi Azikiwe International Airport             Abuja
# AKR        261                                Akure Airport             Akure
# BNI        262                                Benin Airport             Benin
# CBQ        263          Margaret Ekpo International Airport           Calabar
# ENU        264            Akanu Ibiam International Airport             Enugu
# QUS        265                                Gusau Airport             Gusau
# IBA        266                               Ibadan Airport            Ibadan
# ILR        267                 Ilorin International Airport            Ilorin
# ...        ...                                          ...               ...
# \N        6858                               Crocodile Camp        Tsavo East
# \N        6860                        Bungle Bungle Airport     Bungle Bungle
# \N        6866                           Spray View Airport        Spray View
# WSY       6870                    Whitsunday Island Airport      Airlie Beach
# KTR       6897                               Tindal Airport         Katherine
# JDR       6913  Aeroporto Prefeito Octavio de Almeida Neves  Sao Joao del Rei
# ARE       6917              Antonio Nery Juarbe Pol Airport           Arecibo
# RIN       6918                           Ringi Cove Airport        Ringi Cove
# BNY       6919                                      Bellona           Bellona
# BN1       6920                                      Bellona           Bellona
# RMT       6926                             Rimatara Airport          Rimatara
# DRK       6945                            Drake Bay Airport        Puntarenas
# NYT       6949                            Naypyidaw Airport         Naypyidaw
# \N        6950                       Kyaukhtu South Airport           Kyauktu
# \N        6952                             Bokpyinn Airport          Bokepyin
# NIU       6967                                 Naiu Airport              Niau
# QRW       6972                                Warri Airport             Osubi
# IAO       6974                              Siargao Airport           Siargao
# FNE       6976                                 Fane Airport              Fane
# ITK       6977                              Itokama Airport           Itokama
# ONB       6978                               Ononge Airport            Ononge
# TPI       6979                               Tapini Airport            Tapini
# AGL       6980                             Wanigela Airport          Wanigela
# WTP       6981                              Woitape Airport           Woitape
# AWB       6982                                Awaba Airport             Awaba
# TFM       6983                            Telefomin Airport         Telefomin
# \N        6997                               Palmar Airport       Santa Lucia
# CZH       7029                                    Municipal           Corozal
# \N        7055                        Hickam Air Force Base          Honolulu
# CPQ       7125                              Amarais Airport          Campinas
#
#                    Country icaoCode   latitude   longitude altitude timezone  \
# iataCode
# GKA       Papua New Guinea     AYGA  -6.081690  145.391998     5282       10
# MAG       Papua New Guinea     AYMD  -5.207080  145.789001       20       10
# HGU       Papua New Guinea     AYMH  -5.826790  144.296005     5388       10
# LAE       Papua New Guinea     AYNZ  -6.569803  146.725977      239       10
# POM       Papua New Guinea     AYPY  -9.443380  147.220001      146       10
# WWK       Papua New Guinea     AYWK  -3.583830  143.669006       19       10
# TMR                Algeria     DAAT  22.811501    5.451080     4518        1
# COO                  Benin     DBBB   6.357230    2.384350       19        1
# OUA           Burkina Faso     DFFD  12.353200   -1.512420     1037        0
# BOY           Burkina Faso     DFOO  11.160100   -4.330970     1511        0
# ACC                  Ghana     DGAA   5.605190   -0.166786      205        0
# TML                  Ghana     DGLE   9.557190   -0.863214      553        0
# \N                   Ghana     DGLW  10.082700   -2.507690     1060        0
# NYI                  Ghana     DGSN   7.361830   -2.328760     1014        0
# TKD                  Ghana     DGTK   4.896060   -1.774760       21        0
# ABJ          Cote d'Ivoire     DIAP   5.261390   -3.926290       21        0
# BYK          Cote d'Ivoire     DIBK   7.738800   -5.073670     1230        0
# DJO          Cote d'Ivoire     DIDL   6.792810   -6.473190      823        0
# HGO          Cote d'Ivoire     DIKO   9.387180   -5.556660     1214        0
# MJC          Cote d'Ivoire     DIMN   7.272070   -7.587360     1089        0
# SPY          Cote d'Ivoire     DISP   4.746720   -6.660820       26        0
# ASK          Cote d'Ivoire     DIYO   6.903170   -5.365580      699        0
# ABV                Nigeria     DNAA   9.006790    7.263170     1123        1
# AKR                Nigeria     DNAK   7.246740    5.301010     1100        1
# BNI                Nigeria     DNBE   6.316980    5.599500      258        1
# CBQ                Nigeria     DNCA   4.976020    8.347200      210        1
# ENU                Nigeria     DNEN   6.474270    7.561960      466        1
# QUS                Nigeria     DNGU  12.171700    6.696110     1520        1
# IBA                Nigeria     DNIB   7.362460    3.978330      725        1
# ILR                Nigeria     DNIL   8.440210    4.493920     1126        1
# ...                    ...      ...        ...         ...      ...      ...
# \N                   Kenya       \N  -3.070875   39.219431      400        3
# \N               Australia     YBUU -17.545300  128.307007        0        8
# \N                Zimbabwe     FVSV -17.917000   25.816999     3210        2
# WSY              Australia     YWHI -20.276110  148.755000       40       10
# KTR              Australia     YPTN -14.521100  132.378006      443      9.5
# JDR                 Brazil       \N -21.086400  -44.225800     3120       -3
# ARE            Puerto Rico     TJAB  18.450001  -66.675301       23       -4
# RIN        Solomon Islands     AGRC  -8.126390  157.143005        0       11
# BNY        Solomon Islands       \N -11.302000  159.800000        3       11
# BN1        Solomon Islands       \N  15.981667  -11.300000        3        0
# RMT       French Polynesia     NTAM -22.637250 -152.805900       60      -10
# DRK             Costa Rica     MRDK   8.718890  -83.641701       12       -6
# NYT                  Burma     VYEL  19.623501   96.200996      302      6.5
# \N                   Burma     VYXG  21.406700   94.130302     1345      6.5
# \N                   Burma     VYBP  11.149400   98.735901      100      6.5
# NIU       French Polynesia     NTKN -16.119100 -146.368300       50      -10
# QRW                Nigeria     DNSU   5.310000    5.450000       50        1
# IAO            Philippines     RPNS   9.859100  126.014000       10        8
# FNE       Papua New Guinea       \N  -8.550000  147.083000        0       10
# ITK       Papua New Guinea       \N  -9.200000  148.250000        0       10
# ONB       Papua New Guinea       \N  -8.583000  147.200000        0       10
# TPI       Papua New Guinea       \N  -8.350000  146.983000        0       10
# AGL       Papua New Guinea       \N  -9.333000  149.150000        0       10
# WTP       Papua New Guinea       \N  -8.533000  147.250000        0       10
# AWB       Papua New Guinea       \N  -8.014000  142.750000        0       10
# TFM       Papua New Guinea       \N  -5.117000  141.633000        0       10
# \N                    Peru     SLPA -18.971666  -62.975334     1342       -4
# CZH                 Belize       \N  18.382200  -88.411900       40       -6
# \N           United States     PHIK  21.318681 -157.922427       13      -10
# CPQ                 Brazil     SDAM -22.859200  -47.108200     2008       -3
#
#          dst   timezoneOlsonFormat installationType   datasource
# iataCode
# GKA        U  Pacific/Port_Moresby          airport  OurAirports
# MAG        U  Pacific/Port_Moresby          airport  OurAirports
# HGU        U  Pacific/Port_Moresby          airport  OurAirports
# LAE        U  Pacific/Port_Moresby          airport  OurAirports
# POM        U  Pacific/Port_Moresby          airport  OurAirports
# WWK        U  Pacific/Port_Moresby          airport  OurAirports
# TMR        N        Africa/Algiers          airport  OurAirports
# COO        N     Africa/Porto-Novo          airport  OurAirports
# OUA        N    Africa/Ouagadougou          airport  OurAirports
# BOY        N    Africa/Ouagadougou          airport  OurAirports
# ACC        N          Africa/Accra          airport  OurAirports
# TML        N          Africa/Accra          airport  OurAirports
# \N         N          Africa/Accra          airport  OurAirports
# NYI        N          Africa/Accra          airport  OurAirports
# TKD        N          Africa/Accra          airport  OurAirports
# ABJ        N        Africa/Abidjan          airport  OurAirports
# BYK        N        Africa/Abidjan          airport  OurAirports
# DJO        N        Africa/Abidjan          airport  OurAirports
# HGO        N        Africa/Abidjan          airport  OurAirports
# MJC        N        Africa/Abidjan          airport  OurAirports
# SPY        N        Africa/Abidjan          airport  OurAirports
# ASK        N        Africa/Abidjan          airport  OurAirports
# ABV        N          Africa/Lagos          airport  OurAirports
# AKR        N          Africa/Lagos          airport  OurAirports
# BNI        N          Africa/Lagos          airport  OurAirports
# CBQ        N          Africa/Lagos          airport  OurAirports
# ENU        N          Africa/Lagos          airport  OurAirports
# QUS        N          Africa/Lagos          airport  OurAirports
# IBA        N          Africa/Lagos          airport  OurAirports
# ILR        N          Africa/Lagos          airport  OurAirports
# ...       ..                   ...              ...          ...
# \N         U        Africa/Nairobi          unknown         User
# \N         U       Australia/Perth          airport  OurAirports
# \N         U         Africa/Harare          airport  OurAirports
# WSY        O    Australia/Brisbane          airport  OurAirports
# KTR        O      Australia/Darwin          airport  OurAirports
# JDR        S     America/Sao_Paulo          unknown         User
# ARE        N   America/Puerto_Rico          airport  OurAirports
# RIN        U   Pacific/Guadalcanal          airport  OurAirports
# BNY        U   Pacific/Guadalcanal          unknown         User
# BN1        U     Africa/Nouakchott          unknown         User
# RMT        U                    \N          airport  OurAirports
# DRK        N    America/Costa_Rica          airport  OurAirports
# NYT        U          Asia/Rangoon          airport  OurAirports
# \N         U          Asia/Rangoon          airport  OurAirports
# \N         U          Asia/Rangoon          airport  OurAirports
# NIU        U        Pacific/Tahiti          airport  OurAirports
# QRW        U          Africa/Lagos          airport         User
# IAO        N           Asia/Manila          airport  OurAirports
# FNE        U  Pacific/Port_Moresby          airport         User
# ITK        U  Pacific/Port_Moresby          airport         User
# ONB        U  Pacific/Port_Moresby          airport         User
# TPI        U  Pacific/Port_Moresby          airport         User
# AGL        U  Pacific/Port_Moresby          airport         User
# WTP        U  Pacific/Port_Moresby          airport         User
# AWB        U  Pacific/Port_Moresby          airport         User
# TFM        U  Pacific/Port_Moresby          airport         User
# \N         U        America/La_Paz          airport  OurAirports
# CZH        N        America/Belize          unknown         User
# \N         N      Pacific/Honolulu          airport         User
# CPQ        S     America/Sao_Paulo          airport  OurAirports
#
# [1742 rows x 13 columns]

# %%
# top countries
topCountries = pdTropAirports.groupby('Country').count()['Name'].sort_values().tail(10)
display(topCountries)


topCountries.plot(kind="pie")
# Out:
# Country
# Mexico               48
# Thailand             50
# Papua New Guinea     51
# India                58
# Venezuela            58
# Philippines          59
# Colombia             61
# Australia            61
# Indonesia            99
# Brazil              109
# Name: Name, dtype: int64
